# %% [markdown]
# <a href="https://colab.research.google.com/github/yuzonfire907/data-science-2026/blob/main/Pertemuan%201_Yustinus%20Budi%20Kristiawan_240401010299.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pertemuan 1 - Pengenalan Data Science dan Python**
#
# # **Nama : Yustinus Budi Kristiawan**
# # **NIM : 240401010299**
# # **Kelas : IF401**

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Yustinus Budi Kristiawan"   # String
nim = "240401010299"                # String
prodi = "Informatika"               # String
angkatan = 2024                     # Integer
ipk = 3.75                          # Float
aktif = True                        # Boolean

print(f"Nama     : {nama}")
print(f"NIM      : {nim}")
print(f"Prodi    : {prodi}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Yustinus Budi Kristiawan
# NIM      : 240401010299
# Prodi    : Informatika
# Angkatan : 2024
# IPK      : 3.75
# Aktif    : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan dipelajari:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan dipelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Yustinus Budi Kristiawan", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Yustinus Budi Kristiawan dari Informatika, angkatan 2024.

# %% [markdown]
# ## Kesimpulan
#
# Pada aktivitas hands-on ini, saya belajar membuat notebook pertama di Google Colab dan menjalankan kode Python sederhana. Saya juga belajar menggunakan variabel, tipe data dasar, list, perulangan, dan fungsi sederhana.
